# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! unzip /content/drive/MyDrive/img_align_celeba.zip -d /content/drive/MyDrive/img_align_celeba
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/img_align_celeba.zip, /content/drive/MyDrive/img_align_celeba.zip.zip or /content/drive/MyDrive/img_align_celeba.zip.ZIP.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
directory = '/content/drive/MyDrive/img_align_celeba/img_align_celeba'

# Get all images from dir
dataset = tf.keras.preprocessing.image_dataset_from_directory(directory=directory, color_mode='rgb',
                                                   batch_size=128, image_size=(32,32), label_mode=None,
                                                   shuffle=True, seed=42)

# Normalize the data

dataset=dataset.map(lambda x: x /255.00)
# Out:
# Found 0 files.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-3342b15b03a0> in <cell line: 0>()
#       2
#       3 # Get all images from dir
# ----> 4 dataset = tf.keras.preprocessing.image_dataset_from_directory(directory=directory, color_mode='rgb',
#       5                                                    batch_size=128, image_size=(32,32), label_mode=None,
#       6                                                    shuffle=True, seed=42)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     327         )
#     328         if not image_paths:
# --> 329             raise ValueError(
#     330                 f"No images found in directory {directory}. "
#     331                 f"Allowed formats: {ALLOWLIST_FORMATS}"
#
# ValueError: No images found in directory /content/drive/MyDrive/img_align_celeba/img_align_celeba. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')

# %%
# Grid of image
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
it=iter(dataset)
one_batch = next(it).numpy()
images = one_batch[:16,:,:,:]

# show the image

fig = plt.figure(figsize=(10,10))
grid = ImageGrid(fig, 111, nrows_ncols=(4,4),
         axes_pad=0)
for ax,im in zip(grid, images):
    ax.imshow(im)
plt.show()

# %% [markdown]
# GANs-> Generartive Adversarial Network
# Generator, Disc.
# Disc.-> Image Classification Task
# Latent-> Noise

# %%
from tensorflow.keras.layers import Conv2D, LeakyReLU,BatchNormalization, Dropout, Flatten, Dense, Activation, Reshape
from tensorflow.keras import Model, Input

def discriminator_model():
    disc_input = Input(shape=(32,32,3), name='discriminator_network')
    x=Conv2D(filters=64, kernel_size=3, strides=(2,2), padding='same')(disc_input)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)

    x=Conv2D(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)

    x=Conv2D(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)

    x=Conv2D(filters=64, kernel_size=3, strides=(2,2), padding='same')(x)
    x=LeakyReLU()(x)
    x=Dropout(0.2)(x)

    x=Flatten()(x)
    x=Dense(1)(x)

    output = Activation('sigmoid')(x)

    disc=Model(inputs = disc_input, outputs=output)

    return disc

# %%
disc_model = discriminator_model()
disc_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ discriminator_network           │ (None, 32, 32, 3)      │             0 │
# │ (InputLayer)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 16, 16, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 2, 2, 64)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           257 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 297,281 (1.13 MB)
#  Trainable params: 297,281 (1.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.layers import Conv2D, LeakyReLU,BatchNormalization, Dropout, Flatten, Dense, Activation, Reshape, Conv2DTranspose
from tensorflow.keras import Model, Input
def generator_model(z_dim=100):
    gen_input = Input(shape=(z_dim), name='generator_network')

    x = Dense(8*8*3)(gen_input)
    x = Reshape(target_shape=(8,8,3))(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=512, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=256, kernel_size=3, strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=128, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)


    x = Conv2DTranspose(filters=64, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=3, kernel_size=3, strides=(1,1), padding='same')(x)
    fake_images_gen = LeakyReLU()(x)

    model_gen=Model(inputs = gen_input, outputs=fake_images_gen)

    return model_gen

# %%
from tensorflow.keras.layers import Conv2D, LeakyReLU,BatchNormalization, Dropout, Flatten, Dense, Activation, Reshape, Conv2DTranspose
from tensorflow.keras import Model, Input
def generator_model(z_dim=100):
    # The shape argument should be a tuple representing the dimensions of the input.
    # For a latent vector of size 100, the shape should be (100,).
    gen_input = Input(shape=(z_dim,), name='generator_network')

    x = Dense(8*8*3)(gen_input)
    x = Reshape(target_shape=(8,8,3))(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=512, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=256, kernel_size=3, strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=128, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=128, kernel_size=3, strides=(2,2), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)


    x = Conv2DTranspose(filters=64, kernel_size=3, strides=(1,1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(filters=3, kernel_size=3, strides=(1,1), padding='same')(x)
    fake_images_gen = LeakyReLU()(x)

    model_gen=Model(inputs = gen_input, outputs=fake_images_gen)

    return model_gen

# %%
gen_model = generator_model()
gen_model.summary(0)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ generator_network (InputLayer)  │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 192)            │        19,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 8, 8, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 8, 8, 3)        │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 8, 8, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 8, 8, 512)      │        14,336 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 16, 16, 256)    │     1,179,904 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 16, 16, 128)    │       295,040 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 32, 32, 128)    │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 32, 32, 64)     │        73,792 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 32, 32, 3)      │         1,731 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 32, 32, 3)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,736,143 (6.62 MB)
#  Trainable params: 1,733,961 (6.61 MB)
#  Non-trainable params: 2,182 (8.52 KB)

# %%
disc_model = discriminator_model()
gen_model = generator_model()
# Image Classification CNN
# Compile the model that trains disc.
disc_model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
# Compile the model that trains generator
z_dim = 100
disc_model.trainable = False
model_input = Input(shape=(z_dim), name='model_input')
model_output = disc_model(gen_model(model_input))

model = Model(model_input, model_output)

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-fe36f4d8b59a> in <cell line: 0>()
#       2 z_dim = 100
#       3 disc_model.trainable = False
# ----> 4 model_input = Input(shape=(z_dim), name='model_input')
#       5 model_output = disc_model(gen_model(model_input))
#       6
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py in Input(shape, batch_size, dtype, sparse, batch_shape, name, tensor, optional)
#     189     ```
#     190     """
# --> 191     layer = InputLayer(
#     192         shape=shape,
#     193         batch_size=batch_size,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py in __init__(self, shape, batch_size, dtype, sparse, batch_shape, input_tensor, optional, name, **kwargs)
#      90
#      91             if shape is not None:
# ---> 92                 shape = backend.standardize_shape(shape)
#      93                 batch_shape = (batch_size,) + shape
#      94
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/common/variables.py in standardize_shape(shape)
#     560             raise ValueError("Undefined shapes are not supported.")
#     561         if not hasattr(shape, "__iter__"):
# --> 562             raise ValueError(f"Cannot convert '{shape}' to a shape.")
#     563         if config.backend() == "tensorflow":
#     564             if isinstance(shape, tf.TensorShape):
#
# ValueError: Cannot convert '100' to a shape.

# %%
# Compile the model that trains generator
z_dim = 100
disc_model.trainable = False
# The shape argument should be a tuple representing the dimensions of the input.
# For a latent vector of size 100, the shape should be (z_dim,).
model_input = Input(shape=(z_dim,), name='model_input')
model_output = disc_model(gen_model(model_input))

model = Model(model_input, model_output)

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ model_input (InputLayer)        │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_3 (Functional)       │ (None, 32, 32, 3)      │     1,736,143 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_2 (Functional)       │ (None, 1)              │       297,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,033,424 (7.76 MB)
#  Trainable params: 1,733,961 (6.61 MB)
#  Non-trainable params: 299,463 (1.14 MB)

# %%
def train_discriminator(batch, batch_size):
    valid = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    disc_model.train_on_batch(batch, valid)

    noise = np.random.normal(0,1, (batch_size, z_dim))
    gen_image = gen_model.predict(noise)
    disc_model.train_on_batch(gen_image, fake)
def train_generator(batch_size):
    valid = np.ones((batch_size, 1))
    noise = np.random.normal(0,1, (batch_size, z_dim))
    model.train_on_batch(noise, valid)

# %%
def save_image(fake_image, path):
    image = tf.keras.preprocessing.image.array_to_img(fake_image.numpy())
    tf.keras.preprocessing.image.save_img(path, image)
    return image
def generate_and_save_image(path):
    noise = np.random.normal(0,1, (1, z_dim))
    fake_images = gen_model(noise)
    image = save_image(fake_images[0], path)
    plt.imshow(image)
    plt.show()

# %%
for epochs in range(10):
    print(f'No of Epochs-> {epochs}')
    for i,batch in enumerate(dataset):
        train_discriminator(batch, batch.shape[0])
        train_generator(batch.shape[0])
        if i%100==0:
            print(f'Batch Images-> {i}')
            PATH = '/content/drive/MyDrive/img_align_celeba/generate face'
            generate_and_save_image(path = f'{PATH}/epochs_{epochs}batch_{i}.jpg')
# Out:
# No of Epochs-> 0
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:82: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# No of Epochs-> 1
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# No of Epochs-> 2
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# No of Epochs-> 3
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# No of Epochs-> 4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# No of Epochs-> 5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# No of Epochs-> 6
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# No of Epochs-> 7
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# No of Epochs-> 8
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# No of Epochs-> 9
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Batch Images-> 0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Batch Images-> 100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
